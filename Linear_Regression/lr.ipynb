# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../salary_data.csv")

# %%
# Extract features and target
x = data['YearsExperience'].values.reshape(-1, 1)
y = data['Salary'].values.reshape(-1, 1)

# %%
# Create design matrix with bias term
X = np.hstack((np.ones((x.shape[0], 1)), x))

# %%
# Compute beta using Normal Equation
beta = np.linalg.inv(X.T @ X) @ X.T @ y

# %%
# Parameters
beta_0 = beta[0, 0]
beta_1 = beta[1, 0]

# %%
print("Intercept (β0):", beta_0)
print("Slope (β1):", beta_1)
# Out:
# Intercept (β0): 25792.200198668615
# Slope (β1): 9449.962321455085

# %%
# Predictions
y_pred = X @ beta

# Residuals
residuals = y - y_pred

# Residual Sum of Squares
RSS = (residuals.T @ residuals)[0, 0]
print("Residual Sum of Squares (RSS):", RSS)
# Out:
# Residual Sum of Squares (RSS): 938128551.6684293

# %%
# Orthogonality check
print("X^T (y - Xβ):")
print(X.T @ residuals)
# Out:
# X^T (y - Xβ):
# [[9.96806193e-10]
#  [3.40151018e-09]]

# %%
# Plot results
plt.scatter(x, y)
plt.plot(x, y_pred)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Linear Regression using Normal Equation")
plt.show()
